# %%
from arthurai import ArthurAI
from arthurai.common.constants import InputType, OutputType, Stage, ValueType
from arthurai.core.attributes import AttributeCategory
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import pytz

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import joblib

# %% [markdown]
# ## Set up connection to API

# %%
# credentials are being passed to the client via environment variables
connection = ArthurAI()
# Out:
# 2022-07-20 13:26:07,127 - arthurai.client.helper - WARNING - No url scheme provided, defaulting to https
# 2022-07-20 13:26:07,408 - arthurai.client.helper - WARNING - No url scheme provided, defaulting to https
# 2022-07-20 13:26:07,409 - arthurai.client.helper - WARNING - No url scheme provided, defaulting to https

# %% [markdown]
# ## Load data

# %%
# train_data_full contains the X's and the Y's
meps_data = pd.read_csv("data/meps_data.csv")

# quick summary of what meps_data looks like
meps_data.head()
# Out:
#    AGE  RACE  PCS42  MCS42  K6SUM42  UTILIZATION  REGION  SEX  MARRY  FTSTU  \
# 0   44     1  57.76  57.06        1            1       1    2      1     -1
# 1   43     1  59.11  54.10        3            0       1    1      1     -1
# 2   16     1  -1.00  -1.00       -1            0       1    1      5     -1
# 3   13     1  -1.00  -1.00       -1            0       1    1      6     -1
# 4   66     0  22.45  53.13        0            1       1    1      3     -1
#
#    ...  ACTLIM  SOCLIM  COGLIM  DFHEAR42  DFSEE42  ADSMOK42  PHQ242  EMPST  \
# 0  ...       2       2       2         2        2         2       0      1
# 1  ...       2       2       2         2        2         2       0      1
# 2  ...       2       2      -1         2        2        -1      -1      1
# 3  ...       2       2      -1         2        2        -1      -1     -1
# 4  ...       1       1       1         2        1         1       0      4
#
#    POVCAT  INSCOV
# 0       5       1
# 1       5       1
# 2       5       1
# 3       5       1
# 4       1       2
#
# [5 rows x 42 columns]

# %%
# split data into train and test, undersampling test data to knock performance
meps_train, meps_test = train_test_split(meps_data, train_size=0.95, random_state=77)

# split data into X and y
X_train, y_train = meps_train.drop(columns=['UTILIZATION', 'RACE']), meps_train['UTILIZATION']
X_test, y_test = meps_test.drop(columns=['UTILIZATION', 'RACE']), meps_test['UTILIZATION']

# %% [markdown]
# ## Fit scikit-learn model

# %%
# fit model
sk_model = RandomForestClassifier()
sk_model.fit(X_train, y_train)

# save model
joblib.dump(sk_model, "./saved_model/skl_rf.joblib")
# print test accuracy
print(f"Overall Test Accuracy: {(100*accuracy_score(y_test, sk_model.predict(X_test))):.1f}%")
# Out:
# Overall Test Accuracy: 86.0%

# %% [markdown]
# ## Set up ArthurModel
# Everything under this header is *necessary* for an `ArthurModel` to be created; additional functionality is not
# possible until after `model.save()` has been successfully called.
#
# *Some context about this dataset:*
#
# - label: `UTILIZATION`, where 1: >10 visits, 0: <10 visits
#
# - protected attribute: `RACE`, where 1: `White`, 0: `Non-White`

# %%
# uncomment the below if you want to get the same model object that you have already created
# arthur_model = connection.get_model('<YOUR MODEL ID>')

# %%
# Set up ground truth and prediction columns
meps_train = meps_train.rename(columns={'UTILIZATION': "high_utilization"})
# add prediction column to meps_train
meps_train['pred_high_utilization'] = sk_model.predict_proba(X_train)[:,1]
meps_train
# Out:
#        AGE  RACE  PCS42  MCS42  K6SUM42  high_utilization  REGION  SEX  MARRY  \
# 14230   10     0  -1.00  -1.00       -1                 0       3    1      6
# 7611    25     0  42.80  62.26        0                 0       4    2      5
# 2359    69     1  54.53  57.73        0                 1       4    2      3
# 2311    68     1  41.59  65.38        0                 1       2    1      5
# 15308   22     0  56.48  47.77        0                 0       2    1      5
# ...    ...   ...    ...    ...      ...               ...     ...  ...    ...
# 2283    55     0  -1.00  -1.00       -1                 0       3    1      1
# 10196   60     0  56.15  57.16        0                 0       3    2      5
# 11860   16     1  -1.00  -1.00       -1                 0       1    2      5
# 8799    75     0  41.04  66.81        0                 0       3    2      1
# 15063    6     0  -1.00  -1.00       -1                 1       4    2      6
#
#        FTSTU  ...  SOCLIM  COGLIM  DFHEAR42  DFSEE42  ADSMOK42  PHQ242  EMPST  \
# 14230     -1  ...       2      -1         2        2        -1      -1     -1
# 7611      -1  ...       2       2         2        2         2       0      1
# 2359      -1  ...       2       2         2        1         2       0      4
# 2311      -1  ...       2       2         2        2         2       0      4
# 15308      3  ...       2       2         2        2         2       0      1
# ...      ...  ...     ...     ...       ...      ...       ...     ...    ...
# 2283      -1  ...       2       2         2        2        -1      -1      1
# 10196     -1  ...       2       2         2        2         2       0      1
# 11860     -1  ...       2      -1         2        2        -1      -1      4
# 8799      -1  ...       2       2         2        2         2       0      4
# 15063     -1  ...       2      -1         2        2        -1      -1     -1
#
#        POVCAT  INSCOV  pred_high_utilization
# 14230       4       2               0.000000
# 7611        5       3               0.010000
# 2359        3       2               0.740000
# 2311        4       1               0.800000
# 15308       4       1               0.000000
# ...       ...     ...                    ...
# 2283        4       2               0.000000
# 10196       4       1               0.010000
# 11860       4       1               0.324583
# 8799        3       2               0.050000
# 15063       2       2               0.630000
#
# [14891 rows x 43 columns]

# %%
arthur_model = connection.model(partner_model_id=f"MedicalUtilization_FG-{datetime.now().strftime('%Y%m%d%H%M%S')}",
                                display_name="MEPS Medical Utilization Explainability",
                                input_type=InputType.Tabular,
                                output_type=OutputType.Multiclass)

# %%
arthur_model.build(meps_train, non_input_columns=['RACE'],
                   ground_truth_column="high_utilization",
                   pred_to_ground_truth_map={"pred_high_utilization": 1})
# Out:
# 2022-07-20 13:26:38,594 - arthurai.core.models - WARNING - Found one or more categorical attributes. It is suggested to use model.review() to verify all possible categories were inferred correctly for each categorical attribute. To update with new categories, use model.get_attribute(attr_name).set(categories=[cat_1, cat_2, cat_3])
# 2022-07-20 13:26:38,596 - arthurai.core.models - WARNING - Found one or more categorical attributes. It is suggested to use model.review() to verify all possible categories were inferred correctly for each categorical attribute. To update with new categories, use model.get_attribute(attr_name).set(categories=[cat_1, cat_2, cat_3])
# 2022-07-20 13:26:38,598 - arthurai.core.models - INFO - Please review the inferred schema. If everything looks correct, lock in your model by calling arthur_model.save()
#                      name               stage value_type categorical  \
# 0                     AGE      PIPELINE_INPUT    INTEGER       False
# 1                   PCS42      PIPELINE_INPUT      FLOAT       False
# 2                   MCS42      PIPELINE_INPUT      FLOAT       False
# 3                 K6SUM42      PIPELINE_INPUT    INTEGER       False
# 4                  REGION      PIPELINE_INPUT    INTEGER        True
# 5                     SEX      PIPELINE_INPUT    INTEGER        True
# 6                   MARRY      PIPELINE_INPUT    INTEGER        True
# 7                   FTSTU      PIPELINE_INPUT    INTEGER        True
# 8                  ACTDTY      PIPELINE_INPUT    INTEGER        True
# 9                  HONRDC      PIPELINE_INPUT    INTEGER        True
# 10                 RTHLTH      PIPELINE_INPUT    INTEGER        True
# 11                 MNHLTH      PIPELINE_INPUT    INTEGER        True
# 12                 HIBPDX      PIPELINE_INPUT    INTEGER        True
# 13                  CHDDX      PIPELINE_INPUT    INTEGER        True
# 14                 ANGIDX      PIPELINE_INPUT    INTEGER        True
# 15                   MIDX      PIPELINE_INPUT    INTEGER        True
# 16                 OHRTDX      PIPELINE_INPUT    INTEGER        True
# 17                 STRKDX      PIPELINE_INPUT    INTEGER        True
# 18                 EMPHDX      PIPELINE_INPUT    INTEGER        True
# 19                 CHBRON      PIPELINE_INPUT    INTEGER        True
# 20                 CHOLDX      PIPELINE_INPUT    INTEGER        True
# 21               CANCERDX      PIPELINE_INPUT    INTEGER        True
# 22                 DIABDX      PIPELINE_INPUT    INTEGER        True
# 23                 JTPAIN      PIPELINE_INPUT    INTEGER        True
# 24                 ARTHDX      PIPELINE_INPUT    INTEGER        True
# 25               ARTHTYPE      PIPELINE_INPUT    INTEGER        True
# 26                 ASTHDX      PIPELINE_INPUT    INTEGER        True
# 27               ADHDADDX      PIPELINE_INPUT    INTEGER        True
# 28                 PREGNT      PIPELINE_INPUT    INTEGER        True
# 29                 WLKLIM      PIPELINE_INPUT    INTEGER        True
# 30                 ACTLIM      PIPELINE_INPUT    INTEGER        True
# 31                 SOCLIM      PIPELINE_INPUT    INTEGER        True
# 32                 COGLIM      PIPELINE_INPUT    INTEGER        True
# 33               DFHEAR42      PIPELINE_INPUT    INTEGER        True
# 34                DFSEE42      PIPELINE_INPUT    INTEGER        True
# 35               ADSMOK42      PIPELINE_INPUT    INTEGER        True
# 36                 PHQ242      PIPELINE_INPUT    INTEGER        True
# 37                  EMPST      PIPELINE_INPUT    INTEGER        True
# 38                 POVCAT      PIPELINE_INPUT    INTEGER        True
# 39                 INSCOV      PIPELINE_INPUT    INTEGER        True
# 40                   RACE      NON_INPUT_DATA    INTEGER        True
# 41       high_utilization  GROUND_TRUTH_CLASS    INTEGER        True
# 42  pred_high_utilization     PREDICTED_VALUE      FLOAT       False
#
#    is_unique                                         categories  bins  \
# 0      False                                                 []  None
# 1      False                                                 []  None
# 2      False                                                 []  None
# 3      False                                                 []  None
# 4      False   [{value: 1}, {value: 2}, {value: 3}, {value: 4}]  None
# 5      False                           [{value: 1}, {value: 2}]  None
# 6      False  [{value: 1}, {value: 2}, {value: 3}, {value: 4...  None
# 7      False  [{value: 1}, {value: 2}, {value: 3}, {value: -1}]  None
# 31   [None, None]            False
# 32   [None, None]            False
# 33   [None, None]            False
# 34   [None, None]            False
# 35   [None, None]            False
# 36   [None, None]            False
# 37   [None, None]            False
# 38   [None, None]            False
# 39   [None, None]            False
# 40   [None, None]            False
# 41   [None, None]            False
# 42         [0, 1]            False

# %%
# update the `RACE` feature to set bias monitoring
arthur_model.get_attribute('RACE').set(monitor_for_bias=True)
# Out:
# ArthurAttribute(name='RACE', value_type='INTEGER', stage='NON_INPUT_DATA', id=None, label=None, position=0, categorical=True, min_range=None, max_range=None, monitor_for_bias=True, categories=[AttributeCategory(value='0', label=None), AttributeCategory(value='1', label=None)], bins=None, is_unique=False, is_positive_predicted_attribute=False, attribute_link=None, gt_class_link=None)

# %%
# check all the attributes loaded to the model. note that even though you passed in your "real" training
# data, currently the model has no reference to the actual datapoints -- just the properties of the 
# attributes. you will need to set reference data (for data drift detection) later
arthur_model.review()
# Out:
#                      name               stage value_type categorical  \
# 0                     AGE      PIPELINE_INPUT    INTEGER       False
# 1                   PCS42      PIPELINE_INPUT      FLOAT       False
# 2                   MCS42      PIPELINE_INPUT      FLOAT       False
# 3                 K6SUM42      PIPELINE_INPUT    INTEGER       False
# 4                  REGION      PIPELINE_INPUT    INTEGER        True
# 5                     SEX      PIPELINE_INPUT    INTEGER        True
# 6                   MARRY      PIPELINE_INPUT    INTEGER        True
# 7                   FTSTU      PIPELINE_INPUT    INTEGER        True
# 8                  ACTDTY      PIPELINE_INPUT    INTEGER        True
# 9                  HONRDC      PIPELINE_INPUT    INTEGER        True
# 10                 RTHLTH      PIPELINE_INPUT    INTEGER        True
# 11                 MNHLTH      PIPELINE_INPUT    INTEGER        True
# 12                 HIBPDX      PIPELINE_INPUT    INTEGER        True
# 13                  CHDDX      PIPELINE_INPUT    INTEGER        True
# 14                 ANGIDX      PIPELINE_INPUT    INTEGER        True
# 15                   MIDX      PIPELINE_INPUT    INTEGER        True
# 16                 OHRTDX      PIPELINE_INPUT    INTEGER        True
# 17                 STRKDX      PIPELINE_INPUT    INTEGER        True
# 18                 EMPHDX      PIPELINE_INPUT    INTEGER        True
# 19                 CHBRON      PIPELINE_INPUT    INTEGER        True
# 20                 CHOLDX      PIPELINE_INPUT    INTEGER        True
# 21               CANCERDX      PIPELINE_INPUT    INTEGER        True
# 22                 DIABDX      PIPELINE_INPUT    INTEGER        True
# 23                 JTPAIN      PIPELINE_INPUT    INTEGER        True
# 24                 ARTHDX      PIPELINE_INPUT    INTEGER        True
# 25               ARTHTYPE      PIPELINE_INPUT    INTEGER        True
# 26                 ASTHDX      PIPELINE_INPUT    INTEGER        True
# 27               ADHDADDX      PIPELINE_INPUT    INTEGER        True
# 28                 PREGNT      PIPELINE_INPUT    INTEGER        True
# 29                 WLKLIM      PIPELINE_INPUT    INTEGER        True
# 30                 ACTLIM      PIPELINE_INPUT    INTEGER        True
# 31                 SOCLIM      PIPELINE_INPUT    INTEGER        True
# 32                 COGLIM      PIPELINE_INPUT    INTEGER        True
# 38     False  [{value: 1}, {value: 2}, {value: 3}, {value: 4...  None
# 39     False               [{value: 1}, {value: 2}, {value: 3}]  None
# 40     False                           [{value: 0}, {value: 1}]  None
# 41     False                           [{value: 0}, {value: 1}]  None
# 42     False                                                 []  None
#
#             range monitor_for_bias
# 0         [0, 85]            False
# 1   [-9.0, 70.51]            False
# 2   [-9.0, 75.64]            False
# 3        [-9, 24]            False
# 4    [None, None]            False
# 5    [None, None]            False
# 6    [None, None]            False
# 7    [None, None]            False
# 8    [None, None]            False
# 9    [None, None]            False
# 10   [None, None]            False
# 11   [None, None]            False
# 12   [None, None]            False
# 13   [None, None]            False
# 14   [None, None]            False
# 15   [None, None]            False
# 16   [None, None]            False
# 17   [None, None]            False
# 18   [None, None]            False
# 19   [None, None]            False
# 20   [None, None]            False
# 21   [None, None]            False
# 22   [None, None]            False
# 23   [None, None]            False
# 24   [None, None]            False
# 25   [None, None]            False
# 26   [None, None]            False
# 27   [None, None]            False
# 28   [None, None]            False
# 29   [None, None]            False
# 30   [None, None]            False
# 31   [None, None]            False
# 32   [None, None]            False
# 33   [None, None]            False
# 34   [None, None]            False
# 35   [None, None]            False
# 36   [None, None]            False
# 37   [None, None]            False
# 38   [None, None]            False
# 39   [None, None]            False
# 40   [None, None]            False
# 41   [None, None]            False
# 42         [0, 1]            False

# %%
# your model is not uploaded to Arthur until you call model.save(). 
model_id = arthur_model.save()
with open("fullguide_model_id.txt", "w") as f:
    f.write(model_id)
# Out:
# 2022-07-20 13:27:05,478 - arthurai.core.data_service - INFO - Starting upload (0.303 MB in 1 files), depending on data size this may take a few minutes
# 2022-07-20 13:27:07,046 - arthurai.core.data_service - INFO - Upload completed: /var/folders/nz/nl73471j5cl3vy5mnh9108c40000gn/T/tmpotakvcez/3f7d1a36-dd3b-4fb7-9017-a89c33439d74-0.parquet

# %%
# you can fetch a model by ID. for example pull the last-created model:
# with open("fullguide_model_id.txt", "r") as f:
#     model_id = f.read()
# arthur_model = connection.get_model(model_id)

# %% [markdown]
# ## Adding additional functionality
#
# Add to the functionality of the `ArthurModel` that you've created by enabling explainability.

# %% [markdown]
# ### Enabling Explainability

# %%
import os

arthur_model.enable_explainability(
    df=meps_train,
    project_directory=os.path.abspath(""),
    requirements_file="requirements.txt",
    user_predict_function_import_path="entrypoint",
    ignore_dirs = ['./data'],
    streaming_explainability_enabled=True,
)
# Out:
# Ignoring folder: /Users/sarahostermeier/Code/arthur-sandbox/examples/example_projects/healthcare_utilization
# Ignoring folder: /Users/sarahostermeier/Code/arthur-sandbox/examples/example_projects/healthcare_utilization/saved_model
# Ignoring folder: /Users/sarahostermeier/Code/arthur-sandbox/examples/example_projects/healthcare_utilization/__pycache__
# Ignoring folder: /Users/sarahostermeier/Code/arthur-sandbox/examples/example_projects/healthcare_utilization/.ipynb_checkpoints
# Ignoring folder: /Users/sarahostermeier/Code/arthur-sandbox/examples/example_projects/healthcare_utilization/data
# 2022-07-20 13:27:14,461 - arthurai.explainability.arthur_explainer - INFO - Testing model predict() function on provided data
# 2022-07-20 13:27:14,812 - arthurai.explainability.arthur_explainer - INFO - Model predict() function test successful
# 'ok'

# %% [markdown]
# ## Send inferences to Arthur
#
# Finally we'll make some inferences on the test data and register these with Arthur. First we do the inference:

# %%
num_inferences = 350

# create prediction dataframe
pred_df = meps_test.sample(num_inferences).rename(columns={'UTILIZATION': 'high_utilization'})
# predict onto it
preds = sk_model.predict_proba(pred_df.drop(columns=['high_utilization', 'RACE']))
pred_df['pred_high_utilization'] = preds[:, 1]

# %% [markdown]
# And send the data to Arthur:

# %%
# optional metadata: timestamps over the last week
timestamps = pd.date_range(start=datetime.now(pytz.utc) - timedelta(days=7),
                           end=datetime.now(pytz.utc),
                           periods=num_inferences)

# send inferences to Arthur
arthur_model.send_inferences(pred_df, inference_timestamps=timestamps)
# Out:
# 2022-07-20 13:28:05,057 - arthurai.core.models - INFO - 350 rows were missing ground_truth_timestamp fields, so the current time was populated
# 2022-07-20 13:28:05,058 - arthurai.core.models - INFO - 350 rows were missing partner_inference_id fields, so UUIDs were generated, see return values
# {'counts': {'failure': 0, 'success': 350, 'total': 350},
#  'results': [{'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'ULJPu8EAgagzxx8gCNJJZ2'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'jVgVx8PmE9XxFHRU4ekD6c'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'VosCdf5Yy5GiBgBqNxhzsq'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'kCGpsbiHbqc8oTA586Gvkj'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'XLpRPJMcdqtNKFa6ABYQ3z'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'cAP7PBmMViv9FkLTh56Pfm'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'nQwXhwEmBqVWM6Z4yzff7X'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'WoYFiuCseBhfKj2YKi5QQZ'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'doF8MEEnBvWr6JtknQDpu2'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'DpzayWgU3ru2h6ujGComjC'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'j6QsRJgro7zu8M6GEVe9NZ'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'EKaYsfsFPHgMxYApQRBRUL'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'oVDAupAMjcXF4kpXzRsk54'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'XVJkZwRPeKEoE3eC62JJBu'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': '7FXYzSrPygZhwgr8mhzYXd'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'j8wGLq95GfVE6CctbwaxaJ'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'L3XkDyJWRhLv3orTT2aLus'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': '488dSynwVmyR2aXGRU2KML'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'RXAZ3wJki37ny42pEzbY6b'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'gmtcqAaMqhacmDK9B9Fdan'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'Mh9CHjFVRno58GC5XW8ojL'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'jAuDxyykaMc8ezNSq9Jx2x'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'HxEfEhvi4FiTFr373JmUUF'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': '9CzSnw8oRdXJhpY9DtEHHd'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'G4zBuT8Pp5NJRA6T6VEnij'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'fzypYHNYHZs56uuFxfYxiK'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'crRiyJMqzvHbgpscGUFanS'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'DmwTf9bvq9Ew23ReZ4prPs'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'ic6yNYGGwYNz629prWGdqJ'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'oHpaav7XFgNdUV5pCFrvCx'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': '9sHWBaf33vER5Dezr5het9'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'UghbewMNWKPb7MVzKwLVUD'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'Lb4Xawf4NzrniUMyL4c7tv'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'JwFcg8mW95dTzCiG4DRzkj'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'RV6hVKG7SDXvLdAAGUwEtt'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'jM7e34LDNxRuDazzkZCnks'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 'gyiNJwsM7Zt9jdLdijdhaV'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': '5nAKfWuNdKdBfz4vC5HgdU'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': '4yTX3J4kjHhn6A5zkQTZRK'},
#   {'message': 'success',
#    'status': 200,
#    'partner_inference_id': 