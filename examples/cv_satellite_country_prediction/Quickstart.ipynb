# %% [markdown]
# # Functional Map of the World Country Predictor

# %% [markdown]
# ### Imports

# %% [markdown]
# First we'll ensure this environment matches the requirements

# %%
from IPython.display import Image
from PIL import Image as PImage
from os import listdir, path, environ
from uuid import uuid4
from datetime import datetime
import pytz
import pandas as pd
from torch import unsqueeze, no_grad
from torch.nn.functional import softmax
from random import randint

# arthur imports
from arthurai import ArthurAI
from arthurai.common.constants import InputType, OutputType, Stage, ValueType, Enrichment

# project imports
from fmow_model.data import print_dir_counts, random_fname, load_and_preprocess_image, preprocess, \
                 ImageFilesDataset, CATEGORIES, COUNTRY_CODES
from fmow_model.model import new_model, load_model, save_model
from util import create_batch_df, predict_onto_df

# %% [markdown]
# ### Download the Data

# %%
import boto3, tempfile, zipfile
from botocore import UNSIGNED
from botocore.client import Config

s3_client = boto3.resource('s3', config=Config(signature_version=UNSIGNED))
with tempfile.TemporaryDirectory() as tempdir:
    target_path = path.join(tempdir, "data.zip")
    s3_client.Object("s3-bucket-arthur-public", "fmow/fmow-data.zip").download_file(target_path)
    with zipfile.ZipFile(target_path, 'r') as zf:
        zf.extractall()

# %% [markdown]
# ## The Data

# %% [markdown]
# We'll be using [data](https://github.com/fMoW/dataset) from the Functional Map of the World (fMoW) [challenge](https://www.iarpa.gov/challenges/fmow.html), preprocessed by Standford's [WILDS](https://wilds.stanford.edu/datasets/#fmow).
#
# This data consists of satellite images, and the primary challenge is to classify facility, building, and land use from satellite imagery. We'll be using a subset of the data for three of the categories from two countries:

# %%
print(f"categories: {', '.join(CATEGORIES)}")
print(f"countries: {', '.join(COUNTRY_CODES)}\n")
# Out:
# categories: amusement_park, place_of_worship, recreational_facility
# countries: FRA, RUS

# %%
print_dir_counts("fmow-data")
# Out:
# fmow-data/
#   recreational_facility/
#     test/
#       FRA/                    [960 files]
#       RUS/                    [242 files]
#     train/
#       FRA/                    [2240 files]
#       RUS/                    [564 files]
#   amusement_park/
#     test/
#       FRA/                    [151 files]
#       RUS/                    [433 files]
#     train/
#       FRA/                    [351 files]
#       RUS/                    [1008 files]
#   place_of_worship/
#     test/
#       FRA/                    [186 files]
#       RUS/                    [250 files]
#     train/
#       FRA/                    [434 files]
#       RUS/                    [583 files]

# %%
Image(random_fname('place_of_worship'))

# %% [markdown]
# ## The Model

# %% [markdown]
# Rather than predicting which structure is shown in the image, our classifier model will be using [SqueezeNet](https://arxiv.org/abs/1602.07360) to predict which country the image is from.
#
# The model is trained _only_ on pictures of amusement parks. When the model is asked to classify which country images came from, it performs well on images of amusment parks but we'll see performance materially degrade for images of other structures.

# %%
model = load_model('fmow_model/fmow-fra-rus.tmsd')
model._get_name()
# Out:
# 'SqueezeNet'

# %%
# predicting a random image: first element is France, second is Russia

img = PImage.open(random_fname('amusement_park'))
tensor = preprocess(img)
batched = unsqueeze(tensor, dim=0)
with no_grad():
    print(f"prediction: {softmax(model(batched)).numpy()[0]}")
# Out:
# prediction: [0.19135128 0.8086487 ]
# [W NNPACK.cpp:80] Could not initialize NNPACK! Reason: Unsupported hardware.

# %%
train_dir = "fmow-data/amusement_park/train"
test_dir = "fmow-data/amusement_park/test"

df = pd.DataFrame({'satellite_image': [path.join(train_dir, "FRA", x)
                                           for x in listdir(path.join(train_dir, "FRA"))] +
                                          [path.join(train_dir, "RUS", x)
                                           for x in listdir(path.join(train_dir, "RUS"))]})
predict_onto_df(df, model)
df['country'] = df.apply(lambda x: 'france' if "FRA" in x['satellite_image'] else 'russia', axis=1) 
df['feature'] = "amusement_park"
df
# Out:
#                                         satellite_image    russia country  \
# 0     fmow-data/amusement_park/train/FRA/rgb_img_432...  0.544284  france
# 1     fmow-data/amusement_park/train/FRA/rgb_img_432...  0.120464  france
# 2     fmow-data/amusement_park/train/FRA/rgb_img_125...  0.896554  france
# 3     fmow-data/amusement_park/train/FRA/rgb_img_379...  0.400479  france
# 4     fmow-data/amusement_park/train/FRA/rgb_img_126...  0.093965  france
# ...                                                 ...       ...     ...
# 1354  fmow-data/amusement_park/train/RUS/rgb_img_126...  0.940673  russia
# 1355  fmow-data/amusement_park/train/RUS/rgb_img_128...  0.869105  russia
# 1356  fmow-data/amusement_park/train/RUS/rgb_img_130...  0.988033  russia
# 1357  fmow-data/amusement_park/train/RUS/rgb_img_379...  0.861541  russia
# 1358  fmow-data/amusement_park/train/RUS/rgb_img_432...  0.982382  russia
#
#              feature
# 0     amusement_park
# 1     amusement_park
# 2     amusement_park
# 3     amusement_park
# 4     amusement_park
# ...              ...
# 1354  amusement_park
# 1355  amusement_park
# 1356  amusement_park
# 1357  amusement_park
# 1358  amusement_park
#
# [1359 rows x 4 columns]

# %% [markdown]
# ## Arthur

# %% [markdown]
# ### Creating an Arthur Connection

# %%
# our connection will read from the ARTHUR_ENDPOINT_URL and ARTHUR_API_KEY environment variables
# you can specify these here if they're you're running this notebook outside of Arthur's environment,
# or pass the values directly into the 'url' and 'access_key' parameters in the connection creation below

# environ['ARTHUR_ENDPOINT_URL'] = "https://app.arthur.ai"
# environ['ARTHUR_API_KEY'] = "<YOUR API KEY>"

# %%
connection = ArthurAI()

# %% [markdown]
# ### Defining Model

# %% [markdown]
# First we'll register the model with Arthur, supplying metadata about the type of inputs the model expects and outputs it will produce.
#
# The DataFrame printed below will show these attributes: an image input attribute, a prediction attribute for France and for Russia, and ground truth attributes for the correct country label

# %%
arthur_model = connection.model(partner_model_id=f"FMoW_CountryPredictor_QS-{datetime.now().strftime('%Y%m%d%H%M%S')}",
                                display_name="FMoW Country Predictor",
                                input_type=InputType.Image,
                                output_type=OutputType.Multiclass,
                                pixel_height=224,
                                pixel_width=224,
                                is_batch=True)

# %% [markdown]
# We'll use as dataframe as the reference set for Arthur to use for evaluating drift. Arthur will quantify the similary of future images to the reference set. If the inferences that our model receives down the road are different than the ones it trained on, it may be a sign that the model is getting stale and needs to be retrained.

# %%
# our predicted columns "france" and "russia" correspond to the string values "france" and "russia" in the ground truth column "country" respectively
output_mapping = {
    "france" : "france",
    "russia": "russia"
}

arthur_model.build(df,
                   non_input_columns=['feature'],
                   ground_truth_column="country",
                   pred_to_ground_truth_map= output_mapping,
                   positive_predicted_attr = 'russia')
# Out:
# 2022-07-25 13:25:54,475 - arthurai.core.models - WARNING - Found one or more categorical attributes. It is suggested to use model.review() to verify all possible categories were inferred correctly for each categorical attribute. To update with new categories, use model.get_attribute(attr_name).set(categories=[cat_1, cat_2, cat_3])
# 2022-07-25 13:25:54,477 - arthurai.core.models - INFO - Please review the inferred schema. If everything looks correct, lock in your model by calling arthur_model.save()
#               name               stage value_type categorical is_unique  \
# 0  satellite_image      PIPELINE_INPUT      IMAGE       False      True
# 1          feature      NON_INPUT_DATA     STRING        True     False
# 2          country  GROUND_TRUTH_CLASS     STRING        True     False
# 3           france     PREDICTED_VALUE      FLOAT       False     False
# 4           russia     PREDICTED_VALUE      FLOAT       False     False
#
#                            categories  bins         range monitor_for_bias
# 0                                  []  None  [None, None]            False
# 1           [{value: amusement_park}]  None  [None, None]            False
# 2  [{value: france}, {value: russia}]  None  [None, None]            False
# 3                                  []  None        [0, 1]            False
# 4                                  []  None        [0, 1]            False

# %%
# adding other categories that will serve as anomalous later
arthur_model.get_attribute(name="feature").set(categories=['amusement_park', 
                                                           'place_of_worship', 
                                                           'recreational_facility'])
# Out:
# ArthurAttribute(name='feature', value_type='STRING', stage='NON_INPUT_DATA', id=None, label=None, position=0, categorical=True, min_range=None, max_range=None, monitor_for_bias=False, categories=[AttributeCategory(value='amusement_park', label=None), AttributeCategory(value='place_of_worship', label=None), AttributeCategory(value='recreational_facility', label=None)], bins=None, is_unique=False, is_positive_predicted_attribute=False, attribute_link=None, gt_class_link=None)

# %%
arthur_model.review()
# Out:
#               name               stage value_type categorical is_unique  \
# 0  satellite_image      PIPELINE_INPUT      IMAGE       False      True
# 1          feature      NON_INPUT_DATA     STRING        True     False
# 2          country  GROUND_TRUTH_CLASS     STRING        True     False
# 3           france     PREDICTED_VALUE      FLOAT       False     False
# 4           russia     PREDICTED_VALUE      FLOAT       False     False
#
#                                           categories  bins         range  \
# 0                                                 []  None  [None, None]
# 1  [{value: amusement_park}, {value: place_of_wor...  None  [None, None]
# 2                 [{value: france}, {value: russia}]  None  [None, None]
# 3                                                 []  None        [0, 1]
# 4                                                 []  None        [0, 1]
#
#   monitor_for_bias
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False

# %% [markdown]
# If the above looks good, we'll call save to register the model with Arthur and retrieve a Model ID.

# %%
model_id = arthur_model.save()
with open("quickstart_model_id.txt", "w") as f:
    f.write(model_id)
# Out:
# 2022-07-25 13:26:01,227 - arthurai.core.models - INFO - Processing image data, this may take a couple minutes
# 2022-07-25 13:26:05,129 - arthurai.core.models - INFO - Image processing complete!
# 2022-07-25 13:26:05,130 - arthurai.core.data_service - INFO - Starting upload (138.217 MB in 1 files), depending on data size this may take a few minutes
# 2022-07-25 13:26:31,112 - arthurai.core.data_service - INFO - Upload completed: /var/folders/g9/hcpwvt1n62g70yggw4n6kn_w0000gn/T/tmpu89o9nyy/10507ac0-287f-419a-9dda-ddc59d6f21d7.parquet

# %%
# you can fetch a model by ID. for example pull the last-created model:
# with open("quickstart_model_id.txt", "r") as f:
#     model_id = f.read()
# arthur_model = connection.get_model(model_id)

# %% [markdown]
# ### Sending Batches

# %% [markdown]
# Next we'll randomly sample our test data, making predictions and sending them to Arthur.

# %%
def send_df_batch(df, batch_id):
    inferences = []
    for _, row in df.iterrows():
        inf = {'satellite_image': row['satellite_image'],
               'russia': row['russia'],
               'feature': row['feature'],
               'country': row['country']}
        inferences.append(inf)
    return arthur_model.send_inferences(inferences, batch_id=batch_id)

# %%
def create_and_send_batch(category):
    print(f"generating and sending batch for {category}")
    df = create_batch_df(category)
    predict_onto_df(df, model)
    batch_id = category + "-" + str(uuid4()).split("-")[1]
    send_df_batch(df, batch_id)

# %% [markdown]
# We can expect that the model will perform well and have low drift or the batches pulled from the Amusement Park subset.
#
# But as the model is asked to classify Places of Worship and Recreational Facilities it won't perform as well, and we can expect those batches to have higher drift as well.

# %%
create_and_send_batch("amusement_park")
create_and_send_batch("amusement_park")
create_and_send_batch("amusement_park")
create_and_send_batch("place_of_worship")
create_and_send_batch("amusement_park")
create_and_send_batch("recreational_facility")
create_and_send_batch("amusement_park")
create_and_send_batch("place_of_worship")
create_and_send_batch("amusement_park")
create_and_send_batch("recreational_facility")
# Out:
# generating and sending batch for amusement_park
# 2022-07-25 13:26:34,620 - arthurai.core.models - INFO - 83 rows were missing inference_timestamp fields, so the current time was populated
# 2022-07-25 13:26:34,620 - arthurai.core.models - INFO - 83 rows were missing ground_truth_timestamp fields, so the current time was populated
# 2022-07-25 13:26:34,620 - arthurai.core.models - INFO - 83 rows were missing partner_inference_id fields, so UUIDs were generated, see return values
# generating and sending batch for amusement_park
# 2022-07-25 13:26:37,701 - arthurai.core.models - INFO - 59 rows were missing inference_timestamp fields, so the current time was populated
# 2022-07-25 13:26:37,701 - arthurai.core.models - INFO - 59 rows were missing ground_truth_timestamp fields, so the current time was populated
# 2022-07-25 13:26:37,702 - arthurai.core.models - INFO - 59 rows were missing partner_inference_id fields, so UUIDs were generated, see return values
# generating and sending batch for amusement_park
# 2022-07-25 13:26:41,722 - arthurai.core.models - INFO - 73 rows were missing inference_timestamp fields, so the current time was populated
# 2022-07-25 13:26:41,722 - arthurai.core.models - INFO - 73 rows were missing ground_truth_timestamp fields, so the current time was populated
# 2022-07-25 13:26:41,722 - arthurai.core.models - INFO - 73 rows were missing partner_inference_id fields, so UUIDs were generated, see return values
# generating and sending batch for place_of_worship
# 2022-07-25 13:26:45,317 - arthurai.core.models - INFO - 67 rows were missing inference_timestamp fields, so the current time was populated
# 2022-07-25 13:26:45,318 - arthurai.core.models - INFO - 67 rows were missing ground_truth_timestamp fields, so the current time was populated
# 2022-07-25 13:26:45,318 - arthurai.core.models - INFO - 67 rows were missing partner_inference_id fields, so UUIDs were generated, see return values
# generating and sending batch for amusement_park
# 2022-07-25 13:26:49,727 - arthurai.core.models - INFO - 70 rows were missing inference_timestamp fields, so the current time was populated
# 2022-07-25 13:26:49,728 - arthurai.core.models - INFO - 70 rows were missing ground_truth_timestamp fields, so the current time was populated
# 2022-07-25 13:26:49,728 - arthurai.core.models - INFO - 70 rows were missing partner_inference_id fields, so UUIDs were generated, see return values
# generating and sending batch for recreational_facility
# 2022-07-25 13:26:56,394 - arthurai.core.models - INFO - 91 rows were missing inference_timestamp fields, so the current time was populated
# 2022-07-25 13:26:56,394 - arthurai.core.models - INFO - 91 rows were missing ground_truth_timestamp fields, so the current time was populated
# 2022-07-25 13:26:56,395 - arthurai.core.models - INFO - 91 rows were missing partner_inference_id fields, so UUIDs were generated, see return values
# generating and sending batch for amusement_park
# 2022-07-25 13:27:00,566 - arthurai.core.models - INFO - 48 rows were missing inference_timestamp fields, so the current time was populated
# 2022-07-25 13:27:00,567 - arthurai.core.models - INFO - 48 rows were missing ground_truth_timestamp fields, so the current time was populated
# 2022-07-25 13:27:00,567 - arthurai.core.models - INFO - 48 rows were missing partner_inference_id fields, so UUIDs were generated, see return values
# generating and sending batch for place_of_worship
# 2022-07-25 13:27:03,550 - arthurai.core.models - INFO - 44 rows were missing inference_timestamp fields, so the current time was populated
# 2022-07-25 13:27:03,551 - arthurai.core.models - INFO - 44 rows were missing ground_truth_timestamp fields, so the current time was populated
# 2022-07-25 13:27:03,551 - arthurai.core.models - INFO - 44 rows were missing partner_inference_id fields, so UUIDs were generated, see return values
# generating and sending batch for amusement_park
# 2022-07-25 13:27:06,643 - arthurai.core.models - INFO - 72 rows were missing inference_timestamp fields, so the current time was populated
# 2022-07-25 13:27:06,644 - arthurai.core.models - INFO - 72 rows were missing ground_truth_timestamp fields, so the current time was populated
# 2022-07-25 13:27:06,644 - arthurai.core.models - INFO - 72 rows were missing partner_inference_id fields, so UUIDs were generated, see return values
# generating and sending batch for recreational_facility
# 2022-07-25 13:27:09,568 - arthurai.core.models - INFO - 58 rows were missing inference_timestamp fields, so the current time was populated
# 2022-07-25 13:27:09,569 - arthurai.core.models - INFO - 58 rows were missing ground_truth_timestamp fields, so the current time was populated
# 2022-07-25 13:27:09,569 - arthurai.core.models - INFO - 58 rows were missing partner_inference_id fields, so UUIDs were generated, see return values
